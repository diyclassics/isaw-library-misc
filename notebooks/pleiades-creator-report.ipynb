# %%
# Imports

from datetime import datetime

from gzip import decompress
from json import loads

from requests import get

from pprint import pprint

# %%
# Helper function to retrieve json from .gz over http

def get_gzipped_json(url):
    return loads(decompress(get(url).content))

# %%
# Get json

json = get_gzipped_json("http://atlantides.org/downloads/pleiades/json/pleiades-places-latest.json.gz")

# %%
# Get graph data

graph = json['@graph']

# %%
# Extract useful info

ids = [item['id'] for item in graph]
titles = [item['title'] for item in graph]
createds = [datetime.strptime(item['created'].split('T')[0],'%Y-%m-%d') for item in graph]

creators = []

for item in graph:
    item_creators = []
    for creator in item['creators']:
        if creator['username']:
            item_creators.append(creator['username'])
    creators.append(item_creators)    

# TO DO: Add contributor information
# contributors = []

# for item in graph:
#     item_contributors = []
#     for contributor in item['contributors']:
#         if contributor['username']:
#             item_contributors.append(contributor['username'])
#     contributors.append(item_contributors)

# %%
# Helper function to test dates

def valid_date(test, start, end):
    return start < test < end

# %%
# Set up query info

query = 'gmckee'
start_date = '9/1/2018'
end_date = '8/31/2019'

# %%
# Format dates

date_format = "%m/%d/%Y"
start_date_ = datetime.strptime(start_date, date_format)
end_date_ = datetime.strptime(end_date, date_format)

# %%
creator_matches = []

for i, creator in enumerate(creators):
    if query in creator and valid_date(createds[i], start_date_, end_date_):
        creator_matches.append((query, ids[i], titles[i], createds[i]))

creator_matches = sorted(creator_matches, key=lambda x: x[3])

print(f'{query} created {len(creator_matches)} Pleiades records from {start_date_.strftime("%b %d %Y")}-{end_date_.strftime("%b %d %Y")}')
print('-'*10)

for match in creator_matches:
    print(f'{match[0]} is a creator of {match[1]} {match[2]} on {match[3].strftime("%b %d %Y")}')
# Out:
# gmckee created 56 Pleiades records from Sep 01 2018-Aug 31 2019
# ----------
# gmckee is a creator of 398214850 Novaya Beden'ga I on Sep 12 2018
# gmckee is a creator of 743822664 Solenyĭ Dol on Sep 12 2018
# gmckee is a creator of 970142378 Villa di Loron, Cervar on Sep 14 2018
# gmckee is a creator of 84624811 Balochistan on Sep 14 2018
# gmckee is a creator of 714055238 'Ir David/Wadi Hilweh on Sep 14 2018
# gmckee is a creator of 875370975 Bahra 1 on Sep 21 2018
# gmckee is a creator of 184145664 Mortuary Temple of Senwosret III on Sep 25 2018
# gmckee is a creator of 367582654 Tomb of Senwosret III on Sep 25 2018
# gmckee is a creator of 930907033 Levant (region) on Sep 27 2018
# gmckee is a creator of 447634115 Tomb of Rekhmire at Thebes on Oct 08 2018
# gmckee is a creator of 963297878 Telul eth-Thalathat on Oct 09 2018
# gmckee is a creator of 439136375 Northwest Palace at Kalhu on Oct 09 2018
# gmckee is a creator of 540456066 Iberia (modern region/peninsula) on Oct 10 2018
# gmckee is a creator of 845754667 Tel Kabri on Oct 15 2018
# gmckee is a creator of 969121824 Cathedral of St. James, Jerusalem on Oct 15 2018
# gmckee is a creator of 66376536 Temple of Artemis at Sardis on Oct 18 2018
# gmckee is a creator of 45016675 Khirbet Qeiyafa on Oct 23 2018
# gmckee is a creator of 45016676 Jabal al-Bayḍā on Oct 25 2018
# gmckee is a creator of 45016677 Dhāt Kāhl on Oct 25 2018
# gmckee is a creator of 285586942 Klin-Yar on Nov 05 2018
# gmckee is a creator of 523134405 Tomb of Nebamun at Thebes on Nov 30 2018
# gmckee is a creator of 108542250 Nahal Hemar Cave on Dec 11 2018
# gmckee is a creator of 442642787 Abusir South on Dec 17 2018
# gmckee is a creator of 918126100 Stele of Horemheb at Karnak on Dec 17 2018
# gmckee is a creator of 535977538 Saite-Persian cemetery at Abu Sir on Dec 18 2018
# gmckee is a creator of 998604622 Khirbet al-Batrawy on Jan 04 2019
# gmckee is a creator of 575632427 I͡Asinovskiĭ III Kurgan on Jan 22 2019
# gmckee is a creator of 710738630 Khabiṣ on Feb 01 2019
# gmckee is a creator of 99643110 Stary Sad on Feb 05 2019
# gmckee is a creator of 122408432 Silwan necropolis on Feb 14 2019
# gmckee is a creator of 379400932 Kabnak on Feb 14 2019
# gmckee is a creator of 710864305 Shio-Mgvime monastery on Feb 19 2019
# gmckee is a creator of 825074423 Naga ed-Deir on Feb 26 2019
# gmckee is a creator of 492108154 Ananauri Big Kurgan No. 3 on Feb 27 2019
# gmckee is a creator of 384940621 Tell Um Hammad Sharqi on Mar 11 2019
# gmckee is a creator of 229267414 Tell Um Hammad al-Gharbi on Mar 11 2019
# gmckee is a creator of 101126540 Sintashta on Apr 17 2019
# gmckee is a creator of 313840750 Wadi el-Hol on Apr 23 2019
# gmckee is a creator of 214707089 Khirbat Iskandar on Apr 23 2019
# gmckee is a creator of 677382294 Tell Chuēra/Harbe on Apr 24 2019
# gmckee is a creator of 872106931 Sanctuary of Pan at Paneas on Apr 24 2019
# gmckee is a creator of 309640805 Mastaba of Ptahshepses at Abusir on May 07 2019
# gmckee is a creator of 719744901 Cisterns of La Maalga on May 10 2019
# gmckee is a creator of 263142830 Mycenaean cemetery at Achaia Clauss on May 10 2019
# gmckee is a creator of 796757740 Ganeshwar on May 13 2019
# gmckee is a creator of 215749623 Temple of Al-Lat at Palmyra on May 20 2019
# gmckee is a creator of 535233378 Char Bakr on May 31 2019
# gmckee is a creator of 836839127 Theban necropolis on Jun 07 2019
# gmckee is a creator of 586635000 Fort Shalmaneser on Jun 13 2019
# gmckee is a creator of 586635001 Narekavank on Jun 13 2019
# gmckee is a creator of 586635002 Mugharet Abu Halimeh on Jun 13 2019
# gmckee is a creator of 767632326 Temple of the Storm God at Aleppo on Jun 17 2019
# gmckee is a creator of 177059114 Great Palace of Constantinople on Jun 26 2019
# gmckee is a creator of 288089732 Jrvezh on Jun 26 2019
# gmckee is a creator of 629429885 Sultanahmet Camii on Jun 27 2019
# gmckee is a creator of 971703786 Samshvilde on Jul 03 2019

# %%
# # Print report

# for i, contributor in enumerate(contributors):
#     if 'gmckee' in username:
#         print(f'gmckee is a contributor to {ids[i]} {titles[i]} on {createds[i]}')

# %%
# Delete later

# Retrieve sample json by id

[item for item in graph if item['id'] == '236955527']
# Out:
# [{'features': [{'geometry': {'type': 'Point',
#      'coordinates': [63.655488, 44.268062]},
#     'type': 'Feature',
#     'id': 'imagery-location-of-tagisken-plateau',
#     'properties': {'snippet': 'Plateau; AD 1700 - AD 2100',
#      'link': 'https://pleiades.stoa.org/places/236955527/imagery-location-of-tagisken-plateau',
#      'description': 'Representative point derived from Google Earth imagery.',
#      'location_precision': 'precise',
#      'title': 'Imagery location of Tagisken Plateau'}}],
#   'contributors': [{'username': 'jbecker',
#     'homepage': None,
#     'name': 'Jeffrey Becker',
#     'uri': 'https://pleiades.stoa.org/author/jbecker'},
#    {'username': 'thomase',
#     'homepage': None,
#     'name': 'Tom Elliott',
#     'uri': 'https://pleiades.stoa.org/author/thomase'}],
#   'locations': [{'contributors': [{'username': 'jbecker',
#       'homepage': None,
#       'name': 'Jeffrey Becker',
#       'uri': 'https://pleiades.stoa.org/author/jbecker'}],
#     'associationCertainty': 'certain',
#     'attestations': [{'timePeriod': 'modern',
#       'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/modern',
#       'confidence': 'confident',
#       'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'}],
#     'references': [{'alternateURI': '',
#       'accessURI': '',
#       'citationDetail': 'Ris. 1-2',
#       'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeFurther',
#       'shortTitle': 'Итинa & Яблонский 2001',
#       'bibliographicURI': 'http://www.worldcat.org/oclc/49510280',
#       'formattedCitation': 'Итинa, Maриaннa Aлeксaндровна, and Л. Т. Яблонский, Maвзолеи Сeвeрного Taгискена\u202f: Пoздний бронзовый вeк Нижней Сырдарьи (Moсква: Издaтельская фирма ‘Вoстoчная литература РАН’, 2001)',
#       'otherIdentifier': '',
#       'type': 'seeFurther'}],
#     'id': 'imagery-location-of-tagisken-plateau',
#     'featureTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/plateau'],
#     'end': 2100,
#     'title': 'Imagery location of Tagisken Plateau',
#     'provenance': 'Pleiades',
#     'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#     'start': 1700,
#     'locationTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/plateau'],
#     'archaeologicalRemains': 'traces',
#     'details': '',
#     'review_state': 'published',
#     'accuracy': 'https://pleiades.stoa.org/features/metadata/google-earth-and-partners-imagery-2015',
#     'featureType': ['plateau'],
#     'description': 'Representative point derived from Google Earth imagery.',
#     'created': '2017-03-09T16:55:28Z',
#     'geometry': {'type': 'Point', 'coordinates': [63.655488, 44.268062]},
#     'locationType': ['representative'],
#     'uri': 'https://pleiades.stoa.org/places/236955527/imagery-location-of-tagisken-plateau',
#     'creators': [{'username': 'gmckee',
#       'homepage': None,
#       'name': 'Gabriel Mckee',
#       'uri': 'https://pleiades.stoa.org/author/gmckee'}],
#     '@type': 'Location',
#     'history': [{'comment': 'Edited',
#       'modifiedBy': 'jbecker',
#       'modified': '2017-05-10T01:57:33Z'},
#      {'comment': 'Initial revision',
#       'modifiedBy': 'gmckee',
#       'modified': '2017-03-09T16:55:30Z'}]}],
#   'connections': [{'end': None,
#     'description': '',
#     'contributors': [],
#     'created': '2016-12-08T16:28:44Z',
#     'associationCertainty': 'certain',
#     'title': 'Iaxartes/Silis/Tanais fl.',
#     'start': None,
#     'provenance': 'Pleiades',
#     'uri': 'https://pleiades.stoa.org/places/236955527/iaxartes-silis-tanais-fl',
#     'connectionType': 'near',
#     'id': 'iaxartes-silis-tanais-fl',
#     'attestations': [],
#     'history': [{'comment': 'Initial revision',
#       'modifiedBy': 'gmckee',
#       'modified': '2016-12-08T16:28:45Z'}],
#     'connectsTo': 'https://pleiades.stoa.org/places/59844',
#     'details': '',
#     'references': [],
#     'review_state': 'published',
#     'creators': [{'username': 'gmckee',
#       'homepage': None,
#       'name': 'Gabriel Mckee',
#       'uri': 'https://pleiades.stoa.org/author/gmckee'}],
#     '@type': 'Connection',
#     'connectionTypeURI': 'https://pleiades.stoa.org/vocabularies/relationship-types/near'}],
#   'references': [{'alternateURI': '',
#     'accessURI': '',
#     'citationDetail': '',
#     'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeFurther',
#     'shortTitle': 'Итинa & Яблонский, 2001',
#     'bibliographicURI': 'http://www.worldcat.org/oclc/49510280',
#     'formattedCitation': 'Итинa, Maриaннa Aлeксaндровна, and Л. Т. Яблонский, Maвзолеи Сeвeрного Taгискена\u202f: Пoздний бронзовый вeк Нижней Сырдарьи (Moсква: Издaтельская фирма ‘Вoстoчная литература РАН’, 2001)',
#     'otherIdentifier': '',
#     'type': 'seeFurther'}],
#   'names': [{'nameType': 'geographic',
#     'transcriptionAccuracy': 'accurate',
#     'associationCertainty': 'certain',
#     'romanized': 'Tagisken,Tegisken',
#     'attestations': [{'timePeriod': 'modern',
#       'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/modern',
#       'confidence': 'confident',
#       'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident'}],
#     'references': [{'alternateURI': '',
#       'accessURI': '',
#       'citationDetail': '',
#       'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeFurther',
#       'shortTitle': 'Итинa & Яблонский 2001',
#       'bibliographicURI': 'http://www.worldcat.org/oclc/49510280',
#       'formattedCitation': 'Итинa, Maриaннa Aлeксaндровна, and Л. Т. Яблонский, Maвзолеи Сeвeрного Taгискена\u202f: Пoздний бронзовый вeк Нижней Сырдарьи (Moсква: Издaтельская фирма ‘Вoстoчная литература РАН’, 2001)',
#       'otherIdentifier': '',
#       'type': 'seeFurther'}],
#     'id': 'tagisken',
#     'end': 2100,
#     'contributors': [],
#     'provenance': 'Pleiades',
#     'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#     'start': 1700,
#     'details': '',
#     'review_state': 'published',
#     'description': '',
#     'transcriptionCompleteness': 'complete',
#     'language': 'ru',
#     'created': '2016-12-07T15:57:46Z',
#     'uri': 'https://pleiades.stoa.org/places/236955527/tagisken',
#     'creators': [{'username': 'gmckee',
#       'homepage': None,
#       'name': 'Gabriel Mckee',
#       'uri': 'https://pleiades.stoa.org/author/gmckee'}],
#     'attested': 'Taгискен',
#     '@type': 'Name',
#     'history': [{'comment': 'Edited',
#       'modifiedBy': 'gmckee',
#       'modified': '2017-03-09T16:56:50Z'},
#      {'comment': 'Initial revision',
#       'modifiedBy': 'gmckee',
#       'modified': '2016-12-07T15:57:47Z'}]}],
#   'id': '236955527',
#   'subject': ['Saka', 'tumulus', 'necropolis'],
#   'title': 'Tagisken Plateau',
#   'provenance': 'Pleiades',
#   'placeTypeURIs': ['https://pleiades.stoa.org/vocabularies/place-types/plateau'],
#   'details': '<p>The Tagisken plateau contains two burial sites: A larger southern site dated to the early Saka period (7th-5th centuries BCE) and a smaller northern site used throughout the first half of the first millennium BCE (Itina &amp; IAblonskiĭ 2001).</p>',
#   'review_state': 'published',
#   'type': 'FeatureCollection',
#   'description': 'A plateau in modern Uzbekistan near the Aral Sea containing two burial sites dating to the first millennium BCE.',
#   'reprPoint': [63.655488, 44.268062],
#   'placeTypes': ['plateau'],
#   'bbox': [63.655488, 44.268062, 63.655488, 44.268062],
#   'connectsWith': ['https://pleiades.stoa.org/places/59844',
#    'https://pleiades.stoa.org/places/266192488',
#    'https://pleiades.stoa.org/places/20924741'],
#   'rights': 'Copyright © The Contributors. Sharing and remixing permitted under terms of the Creative Commons Attribution 3.0 License (cc-by).',
#   'created': '2016-12-07T15:48:39Z',
#   'uri': 'https://pleiades.stoa.org/places/236955527',
#   'creators': [{'username': 'gmckee',
#     'homepage': None,
#     'name': 'Gabriel Mckee',
#     'uri': 'https://pleiades.stoa.org/author/gmckee'}],
#   '@type': 'Place',
#   'history': [{'comment': 'Edited',
#     'modifiedBy': 'gmckee',
#     'modified': '2017-03-09T16:43:11Z'},
#    {'comment': 'updating to reflect info only about ',
#     'modifiedBy': 'thomase',
#     'modified': '2017-03-08T19:43:36Z'},
#    {'comment': 'Edited',
#     'modifiedBy': 'jbecker',
#     'modified': '2016-12-09T14:38:24Z'},
#    {'comment': 'Edited',
#     'modifiedBy': 'gmckee',
#     'modified': '2016-12-07T15:58:28Z'},
#    {'comment': 'Initial revision',
#     'modifiedBy': 'gmckee',
#     'modified': '2016-12-07T15:48:46Z'}]}]

# %%
# Sample json, extra-print printed

ks = list(graph[3].keys())
for item in ks:
    print(item, '\n----------')
    pprint(graph[3][item])
    print('----------\n')
# Out:
# features
# ----------
# [{'geometry': {'coordinates': [[[-2.0, 38.0],
#                                 [-2.0, 39.0],
#                                 [-1.0, 39.0],
#                                 [-1.0, 38.0],
#                                 [-2.0, 38.0]]],
#                'type': 'Polygon'},
#   'id': 'batlas-location',
#   'properties': {'description': '',
#                  'link': 'https://pleiades.stoa.org/places/265877/batlas-location',
#                  'location_precision': 'rough',
#                  'snippet': 'Unknown; 330 BC - AD 300',
#                  'title': 'Barrington Atlas location'},
#   'type': 'Feature'}]
# ----------
#
# contributors
# ----------
# [{'name': 'R. Warner', 'username': None},
#  {'name': 'R. Talbert', 'username': None},
#  {'homepage': None,
#   'name': 'Sean Gillies',
#   'uri': 'https://pleiades.stoa.org/author/sgillies',
#   'username': 'sgillies'},
#  {'homepage': None,
#   'name': 'Tom Elliott',
#   'uri': 'https://pleiades.stoa.org/author/thomase',
#   'username': 'thomase'},
#  {'homepage': None,
#   'name': 'Jeffrey Becker',
#   'uri': 'https://pleiades.stoa.org/author/jbecker',
#   'username': 'jbecker'}]
# ----------
#
# locations
# ----------
# [{'@type': 'Location',
#   'accuracy': None,
#   'archaeologicalRemains': 'unknown',
#   'associationCertainty': 'certain',
#   'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#   'attestations': [{'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'hellenistic-republican',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/hellenistic-republican'},
#                    {'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'roman',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/roman'}],
#   'contributors': [{'name': 'R. Warner', 'username': None},
#                    {'name': 'R. Talbert', 'username': None},
#                    {'name': 'T. Elliott', 'username': None},
#                    {'homepage': None,
#                     'name': 'Sean Gillies',
#                     'uri': 'https://pleiades.stoa.org/author/sgillies',
#                     'username': 'sgillies'}],
#   'created': '2010-09-24T19:02:24Z',
#   'creators': [{'name': 'P.O. Spann', 'username': None}],
#   'description': '',
#   'details': '',
#   'end': 300,
#   'featureType': ['unknown'],
#   'featureTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/unknown'],
#   'geometry': {'coordinates': [[[-2.0, 38.0],
#                                 [-2.0, 39.0],
#                                 [-1.0, 39.0],
#                                 [-1.0, 38.0],
#                                 [-2.0, 38.0]]],
#                'type': 'Polygon'},
#   'history': [{'comment': 'Global migration and reindexing of citations and '
#                           'provenance, February 2012',
#                'modified': '2012-02-15T03:50:57Z',
#                'modifiedBy': 'admin'}],
#   'id': 'batlas-location',
#   'locationType': ['representative'],
#   'locationTypeURI': ['https://pleiades.stoa.org/vocabularies/place-types/unknown'],
#   'provenance': 'Barrington Atlas: BAtlas 27 D3 Contestania',
#   'references': [],
#   'review_state': 'published',
#   'start': -330,
#   'title': 'Barrington Atlas location',
#   'uri': 'https://pleiades.stoa.org/places/265877/batlas-location'}]
# ----------
#
# connections
# ----------
# []
# ----------
#
# references
# ----------
# [{'accessURI': '',
#   'alternateURI': '',
#   'bibliographicURI': 'http://openlibrary.org/works/OL8327792W',
#   'citationDetail': '',
#   'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeFurther',
#   'formattedCitation': 'BAtlas 27 D3 Contestania',
#   'otherIdentifier': ' ',
#   'shortTitle': '',
#   'type': 'seeFurther'},
#  {'accessURI': '',
#   'alternateURI': '',
#   'bibliographicURI': 'http://atlantides.org/bibliography/t.html#Tovar-1989',
#   'citationDetail': '',
#   'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeFurther',
#   'formattedCitation': 'Tovar 1989, 31, 189-214',
#   'otherIdentifier': '',
#   'shortTitle': '',
#   'type': 'seeFurther'},
#  {'accessURI': 'https://en.wikipedia.org/wiki/Contestani',
#   'alternateURI': '',
#   'bibliographicURI': 'https://www.zotero.org/groups/2533/items/CI6F6W7W',
#   'citationDetail': 'Contestani',
#   'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/seeAlso',
#   'formattedCitation': 'Wikipedia: the free encyclopedia that anyone can edit '
#                        '(2001-), Contestani.',
#   'otherIdentifier': ' ',
#   'shortTitle': 'Wikipedia (English)',
#   'type': 'seeAlso'},
#  {'accessURI': 'http://latin.packhum.org/loc/978/1/223/291-301,625-635',
#   'alternateURI': '',
#   'bibliographicURI': '',
#   'citationDetail': '',
#   'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/citesAsEvidence',
#   'formattedCitation': 'Plin. HN (Mayhoff: PHI) 3.19.5, 3.20.3',
#   'otherIdentifier': '',
#   'shortTitle': '',
#   'type': 'citesAsEvidence'}]
# ----------
#
# names
# ----------
# [{'@type': 'Name',
#   'associationCertainty': 'certain',
#   'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#   'attestations': [{'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'hellenistic-republican',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/hellenistic-republican'},
#                    {'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'roman',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/roman'}],
#   'attested': 'Contestania',
#   'contributors': [{'name': 'R. Warner', 'username': None},
#                    {'name': 'R. Talbert', 'username': None},
#                    {'homepage': None,
#                     'name': 'Sean Gillies',
#                     'uri': 'https://pleiades.stoa.org/author/sgillies',
#                     'username': 'sgillies'},
#                    {'homepage': None,
#                     'name': 'Tom Elliott',
#                     'uri': 'https://pleiades.stoa.org/author/thomase',
#                     'username': 'thomase'},
#                    {'homepage': None,
#                     'name': 'Jeffrey Becker',
#                     'uri': 'https://pleiades.stoa.org/author/jbecker',
#                     'username': 'jbecker'}],
#   'created': '2010-09-24T19:02:24Z',
#   'creators': [{'name': 'P.O. Spann', 'username': None}],
#   'description': '',
#   'details': '',
#   'end': 300,
#   'history': [{'comment': 'added reference Pliny HN',
#                'modified': '2016-12-15T02:27:38Z',
#                'modifiedBy': 'jbecker'},
#               {'comment': 'Global migration and reindexing of citations and '
#                           'provenance, February 2012',
#                'modified': '2012-02-15T03:50:57Z',
#                'modifiedBy': 'admin'}],
#   'id': 'contestania',
#   'language': 'la',
#   'nameType': 'geographic',
#   'provenance': 'Barrington Atlas: BAtlas 27 D3 Contestania',
#   'references': [{'accessURI': 'http://latin.packhum.org/loc/978/1/223/291-301,625-635',
#                   'alternateURI': '',
#                   'bibliographicURI': '',
#                   'citationDetail': '',
#                   'citationTypeURI': 'https://pleiades.stoa.org/vocabularies/feature-type/citesAsEvidence',
#                   'formattedCitation': 'Plin. HN (Mayhoff: PHI) 3.19.5, 3.20.3',
#                   'otherIdentifier': '',
#                   'shortTitle': '',
#                   'type': 'citesAsEvidence'}],
#   'review_state': 'published',
#   'romanized': 'Contestania',
#   'start': -330,
#   'transcriptionAccuracy': 'accurate',
#   'transcriptionCompleteness': 'complete',
#   'uri': 'https://pleiades.stoa.org/places/265877/contestania'},
#  {'@type': 'Name',
#   'associationCertainty': 'certain',
#   'associationCertaintyURI': 'https://pleiades.stoa.org/vocabularies/association-certainty/certain',
#   'attestations': [{'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'hellenistic-republican',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/hellenistic-republican'},
#                    {'confidence': 'confident',
#                     'confidenceURI': 'https://pleiades.stoa.org/vocabularies/attestation-confidence/confident',
#                     'timePeriod': 'roman',
#                     'timePeriodURI': 'https://pleiades.stoa.org/vocabularies/time-periods/roman'}],
#   'attested': '',
#   'contributors': [{'name': 'R. Warner', 'username': None},
#                    {'name': 'R. Talbert', 'username': None},
#                    {'name': 'T. Elliott', 'username': None},
#                    {'homepage': None,
#                     'name': 'Sean Gillies',
#                     'uri': 'https://pleiades.stoa.org/author/sgillies',
#                     'username': 'sgillies'}],
#   'created': '2010-09-24T19:02:24Z',
#   'creators': [{'name': 'P.O. Spann', 'username': None}],
#   'description': '',
#   'details': '',
#   'end': 300,
#   'history': [{'comment': 'Global migration and reindexing of citations and '
#                           'provenance, February 2012',
#                'modified': '2012-02-15T03:50:57Z',
#                'modifiedBy': 'admin'},
#               {'comment': 'Time periods copied from sibling. See '
#                           'http://atlantides.org/trac/pleiades/wiki/PlaceUpgradesAndMigrations',
#                'modified': '2011-01-20T03:26:47Z',
#                'modifiedBy': 'sgillies'}],
#   'id': 'contestani',
#   'language': '',
#   'nameType': 'geographic',
#   'provenance': 'Barrington Atlas: BAtlas 27 D3 Contestania',
#   'references': [],
#   'review_state': 'published',
#   'romanized': 'Contestani',
#   'start': -330,
#   'transcriptionAccuracy': 'accurate',
#   'transcriptionCompleteness': 'complete',
#   'uri': 'https://pleiades.stoa.org/places/265877/contestani'}]
# ----------
#
# id
# ----------
# '265877'
# ----------
#
# subject
# ----------
# []
# ----------
#
# title
# ----------
# 'Contestania'
# ----------
#
# provenance
# ----------
# 'Barrington Atlas: BAtlas 27 D3 Contestania'
# ----------
#
# placeTypeURIs
# ----------
# ['https://pleiades.stoa.org/vocabularies/place-types/region']
# ----------
#
# details
# ----------
# ('<p>The Barrington Atlas Directory notes: SE coastal area, E Bastetania up to '
#  'R. Júcar (Xúquer)</p>')
# ----------
#
# review_state
# ----------
# 'published'
# ----------
#
# type
# ----------
# 'FeatureCollection'
# ----------
#
# description
# ----------
# 'An ancient place, cited: BAtlas 27 D3 Contestania'
# ----------
#
# reprPoint
# ----------
# [-0.515639, 38.988847]
# ----------
#
# placeTypes
# ----------
# ['region']
# ----------
#
# bbox
# ----------
# [-0.515639, 38.988847, -0.515639, 38.988847]
# ----------
#
# connectsWith
# ----------
# ['https://pleiades.stoa.org/places/266018']
# ----------
#
# rights
# ----------
# ('Copyright © The Contributors. Sharing and remixing permitted under terms of '
#  'the Creative Commons Attribution 3.0 License (cc-by).')
# ----------
#
# created
# ----------
# '2010-09-24T19:02:24Z'
# ----------
#
# uri
# ----------
# 'https://pleiades.stoa.org/places/265877'
# ----------
#
# creators
# ----------
# [{'name': 'P.O. Spann', 'username': None}]
# ----------
#
# @type
# ----------
# 'Place'
# ----------
#
# history
# ----------
# [{'comment': 'added reference to Pliny HN',
#   'modified': '2016-12-15T02:27:00Z',
#   'modifiedBy': 'jbecker'},
#  {'comment': 'added reference',
#   'modified': '2014-01-11T03:27:21Z',
#   'modifiedBy': 'jbecker'},
#  {'comment': 'Global migration and reindexing of citations and provenance, '
#              'February 2012',
#   'modified': '2012-02-15T03:50:56Z',
#   'modifiedBy': 'admin'},
#  {'comment': 'Detail text updated from former modernLocation. See '
#              'http://atlantides.org/trac/pleiades/wiki/PlaceDetailsUpgrade',
#   'modified': '2011-01-14T19:22:00Z',
#   'modifiedBy': 'sgillies'}]
# ----------
